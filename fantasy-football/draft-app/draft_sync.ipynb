# %%
from sleeper_wrapper import League

# %%
league_id = 1001245231355863040
league = League(league_id)

# %%
league.get_all_drafts()
# Out:
# [{'type': 'snake',
#   'status': 'drafting',
#   'start_time': 1693170315478,
#   'sport': 'nfl',
#   'settings': {'teams': 10,
#    'slots_wr': 2,
#    'slots_te': 1,
#    'slots_rb': 2,
#    'slots_qb': 1,
#    'slots_k': 1,
#    'slots_flex': 1,
#    'slots_def': 1,
#    'slots_bn': 6,
#    'rounds': 15,
#    'reversal_round': 0,
#    'player_type': 0,
#    'pick_timer': 120,
#    'nomination_timer': 60,
#    'enforce_position_limits': 1,
#    'cpu_autopick': 1,
#    'autostart': 0,
#    'autopause_start_time': 360,
#    'autopause_end_time': 1080,
#    'autopause_enabled': 0,
#    'alpha_sort': 0},
#   'season_type': 'regular',
#   'season': '2023',
#   'metadata': {'scoring_type': 'ppr',
#    'name': '2Balls1Kupp',
#    'description': ''},
#   'league_id': '1001245231355863040',
#   'last_picked': 1693170766561,
#   'last_message_time': 1693170779463,
#   'last_message_id': '1001634482773929984',
#   'draft_order': {'730845846408687616': 4,
#    '607721733801205760': 9,
# ...

# %%
league.get_draft(1001245232471658496)
# Out:
# [{'round': 1,
#   'roster_id': 10,
#   'player_id': '6794',
#   'picked_by': '607689091164745728',
#   'pick_no': 1,
#   'metadata': {'years_exp': '3',
#    'team': 'MIN',
#    'status': 'Active',
#    'sport': 'nfl',
#    'position': 'WR',
#    'player_id': '6794',
#    'number': '18',
#    'news_updated': '1691706922962',
#    'last_name': 'Jefferson',
#    'injury_status': '',
#    'first_name': 'Justin'},
#   'is_keeper': None,
#   'draft_slot': 1,
#   'draft_id': '1001245232471658496'},
#  {'round': 1,
#   'roster_id': 9,
#   'player_id': '7564',
#   'picked_by': '1001396608614936576',
#   'pick_no': 2,
#   'metadata': {'years_exp': '2',
#    'team': 'CIN',
#    'status': 'Active',
#    'sport': 'nfl',
#    'position': 'WR',
#    'player_id': '7564',
#    'number': '1',
#    'news_updated': '1691862347355',
#    'last_name': 'Chase',
#    'injury_status': '',
#    'first_name': "Ja'Marr"},
#   'is_keeper': None,
#   'draft_slot': 2,
#   'draft_id': '1001245232471658496'},
# ...
